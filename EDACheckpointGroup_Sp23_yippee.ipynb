# %% [markdown]
# # COGS 108 - Data Checkpoint
# ## Group: yippee!

# %% [markdown]
# # Names
#
# - Mariana Villena
# - Akanksha Pandey
# - Rappel Ricafort
# - Justin Lau
# - Amaar Valliani

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# What are the key success factors for electric vehicle companies in terms of pricing and product features?
#
# Subquestions:
#
# * How has Tesla's success been affected by classical and/or emerging car companies' EV models?
# * How have emerging EV companies entered the market and what success have they had?
# * When did Classical car companies enter the EV market and how successful were they?

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# - Dataset Name: Cheapest Electric Cars 2023
# - Link to the dataset: [Kaggle Link](https://www.kaggle.com/datasets/kkhandekar/cheapest-electric-cars?resource=download)
# - Number of observations: 308
#
# This dataset features 308 EV models, their prices (in Germany), Acceleration, Range, Efficiency, Top Speed, type of drive, number of seats, and Fast Charge Speed.
#
# - Dataset Name: Stock Market Analysis of TESLA Inc from 2010 to 2022
# - Link to the dataset: [Kaggle Link](https://www.kaggle.com/datasets/whenamancodes/tesla-inc-stock-market-analysis-founding-years)
# - Number of observations: 3077
#
# This dataset features the stock information of Tesla (the High and Low prices of the day, the opening, adjusted closing, and closing prices, the volume sold in 2010-2022).
#
# We will be finding the corresponding stock information of the companies listed in the Cheapest Electric Cars dataset and modeling how car features and price correspond to the stock performance of a company. Thus, we will add the company's average stock performance of each car model's year to a combined dataset.

# %% [markdown]
# # Setup

# %%
# %matplotlib inline

import numpy as np
import pandas as pd

## seaborn for plotting
import seaborn as sns
sns.set(font_scale=1.2, style="white")

# import matplotlib for plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.style as style
# set plotting size parameter
plt.rcParams['figure.figsize'] = (12, 5)

# improve resolution
# %config InlineBackend.figure_format ='retina'

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# We first downloaded the appropriate CSV files- one for each dataset described above.
# Then, we created the `cheapEVs` dataframe, which we cleaned by turning all string sections of measurements into floats or ints using the `dataToFloat()` function. Next, we standardized the prices to USD and extracted data from the `Subtitle` column.
# We then created the `teslaStock` dataframe, which we cleaned by converting the date to datetime format, and creating an average daily stock price column, or `AvgHighLow`. Then, we averaged all the daily stock prices by the years available, stored in `year_avg_tesla_stock`.

# %%
# read data of the cheapest electric cars sold in 2023 and check out the dataframe
cheapEVsPath = 'csvData/Cheapestelectriccars-EVDatabase_2023.csv'
cheapEVs = pd.read_csv(cheapEVsPath)
cheapEVs
# Out:
#                                    Name  \
# 0             Lucid Air Dream Edition P
# 1                Porsche Taycan Turbo S
# 2                     Audi e-tron GT RS
# 3                 Renault Zoe ZE50 R110
# 4                     Audi Q4 e-tron 35
# ..                                  ...
# 304                 Volkswagen ID.7 Pro
# 305               Volkswagen ID.7 Pro S
# 306  Polestar 4 Long Range Single Motor
# 307    Polestar 4 Long Range Dual Motor
# 308            Maserati Grecale Folgore
#
#                                               Subtitle Acceleration  TopSpeed  \
# 0    118 kWh useable battery          Available sin...      2.7 sec  270 km/h
# 1    83.7 kWh useable battery          Available si...      2.8 sec  260 km/h
# 2    85 kWh useable battery          Available sinc...      3.3 sec  250 km/h
# 3    52 kWh useable battery          Available sinc...     11.4 sec  135 km/h
# 4    52 kWh useable battery          Available sinc...      9.0 sec  160 km/h
# ..                                                 ...          ...       ...
# 304  77 kWh useable battery          Expected from ...      8.0 sec  180 km/h
# 305  86 kWh useable battery          Expected from ...      7.0 sec  180 km/h
# 306  94 kWh useable battery          Expected from ...      7.4 sec  180 km/h
# 307  94 kWh useable battery          Expected from ...      3.8 sec  200 km/h
# 308  95 kWh useable battery          Expected from ...      4.1 sec  220 km/h
#
#       Range Efficiency FastChargeSpeed              Drive  NumberofSeats  \
# 0    645 km  183 Wh/km        820 km/h    All Wheel Drive              5
# 1    400 km  209 Wh/km        980 km/h    All Wheel Drive              4
# 2    405 km  210 Wh/km       1000 km/h    All Wheel Drive              4
# 3    315 km  165 Wh/km        230 km/h  Front Wheel Drive              5
# 4    285 km  182 Wh/km        360 km/h   Rear Wheel Drive              5
# ..      ...        ...             ...                ...            ...
# 304  470 km  164 Wh/km        700 km/h   Rear Wheel Drive              5
# 305  520 km  165 Wh/km        800 km/h   Rear Wheel Drive              5
# 306  510 km  184 Wh/km        760 km/h   Rear Wheel Drive              5
# 307  475 km  198 Wh/km        710 km/h    All Wheel Drive              5
# 308  405 km  235 Wh/km        440 km/h    All Wheel Drive              5
#
#     PriceinGermany PriceinUK
# 0         €218,000       NaN
# 1         €189,668  £142,400
# 2         €146,050  £115,000
# 3          €36,840       NaN
# 4              NaN       NaN
# ..             ...       ...
# 304        €55,000   £53,000
# 305        €60,000   £56,000
# 306        €60,000   £55,000
# 307        €65,000   £60,000
# 308            NaN  £135,000
#
# [309 rows x 11 columns]

# %%
cheapEVs.describe()
# Out:
#        NumberofSeats
# count     309.000000
# mean        5.284790
# std         0.978567
# min         2.000000
# 25%         5.000000
# 50%         5.000000
# 75%         5.000000
# max         7.000000

# %%
# will quantify all numeric data into either a float or integer based on the type
def dataToNum(str_in):
    try:
        if(not isinstance(str_in, str)): # in case input is not a string
            return str_in
        
        str_in = str_in.lower()
        str_in = str_in.strip()

        if 'km/h' in str_in: # fast charge speed and top speed
            str_in = str_in.replace('km/h', '')
            output = int(str_in)
        elif 'wh/km' in str_in: # efficiency
            str_in = str_in.replace('wh/km', '')
            output = int(str_in)
        elif 'km' in str_in: # range
            str_in = str_in.replace('km', '')
            output = int(str_in)
        elif 'sec' in str_in: # acceleration
            str_in = str_in.replace(' sec', '')
            output = float(str_in)
        elif '€' in str_in: # price in Germany (euros)
            str_in = str_in.replace('€', '')
            str_in = str_in.replace(',','')
            output = int(str_in)
        elif '£' in str_in: #price in UK (pounds)
            str_in = str_in.replace('£', '')
            str_in = str_in.replace(',','')
            output = int(str_in)
        else: # handles null values
            output = np.nan
    except:
        output = np.nan     
    return output

# %%
cheapEVs["TopSpeed"] = cheapEVs["TopSpeed"].apply(dataToNum)
cheapEVs["FastChargeSpeed"] = cheapEVs["FastChargeSpeed"].apply(dataToNum)
cheapEVs['Acceleration'] = cheapEVs['Acceleration'].apply(dataToNum)
cheapEVs['Efficiency'] = cheapEVs['Efficiency'].apply(dataToNum)
cheapEVs['Range'] = cheapEVs['Range'].apply(dataToNum)
cheapEVs['PriceinGermany'] = cheapEVs['PriceinGermany'].apply(dataToNum)
cheapEVs['PriceinUK'] = cheapEVs['PriceinUK'].apply(dataToNum)

# %%
# to standardize prices to USD and consolidate missing prices in one of the two 
#                           PriceinGermany and PriceinUK columns but not in both.
# conversion rates are as of May 17th
def priceToUSD(priceEuro,pricePound):
    output = np.nan
    if(not np.isnan(priceEuro)): # price in Germany (euros) will have priority for sake of consistency
        output = priceEuro*(1.08)
    elif(not np.isnan(pricePound)):
        output = pricePound*(1.25)
    return output

# %%
cheapEVs['PriceinUSD'] = cheapEVs.apply(lambda x: priceToUSD(x.PriceinGermany, x.PriceinUK), axis=1)

# %%
# there is lots of data in the Subtitle column; we can extract data on the battery, 
#                                           availability, and release date from this
cheapEVs.Subtitle
# Out:
# 0      118 kWh useable battery          Available sin...
# 1      83.7 kWh useable battery          Available si...
# 2      85 kWh useable battery          Available sinc...
# 3      52 kWh useable battery          Available sinc...
# 4      52 kWh useable battery          Available sinc...
#                              ...
# 304    77 kWh useable battery          Expected from ...
# 305    86 kWh useable battery          Expected from ...
# 306    94 kWh useable battery          Expected from ...
# 307    94 kWh useable battery          Expected from ...
# 308    95 kWh useable battery          Expected from ...
# Name: Subtitle, Length: 309, dtype: object

# %%
# function to extract the battery data from the Subtitle column
def batteryData(str_in):
    try:
        if(not isinstance(str_in, str)):
            return str_in
        
        str_in = str_in.lower()
        str_in = str_in.strip()

        if 'kwh' in str_in:
            str_in = str_in.partition('kwh')[0]
            output = float(str_in)
        else:
            output = np.nan
    except:
        output = np.nan     
    return output

# %%
cheapEVs['BatteryCapacity'] = cheapEVs['Subtitle'].apply(batteryData)

# %%
# function to extract the availability data from the Subtitle column
def availability(str_in):
    try:
        if(not isinstance(str_in, str)):
            return False
        
        str_in = str_in.lower()
        str_in = str_in.strip()

        if 'available' in str_in:
            output = True
        else:
            output = False
    except:
        output = False     
    return output

# %%
cheapEVs['Available'] = cheapEVs['Subtitle'].apply(availability)

# %%
# function to extract the release date data from the Subtitle column
def release(str_in):
    try:
        if(not isinstance(str_in, str)):
            return ""
        
        str_in = str_in.lower()
        str_in = str_in.strip()

        str_in = str_in.split(' ')
        month = str_in[-2]
        year = str_in[-1]
        return (month +" "+ year)
    except:
        output = ""
    return output

# %%
cheapEVs['Release'] = cheapEVs['Subtitle'].apply(release)
# now that we have extracted the useful data from the column, we can drop it
cheapEVs = cheapEVs.drop(columns=['Subtitle'])

# %%
cheapEVs
# Out:
#                                    Name  Acceleration  TopSpeed  Range  \
# 0             Lucid Air Dream Edition P           2.7       270    645
# 1                Porsche Taycan Turbo S           2.8       260    400
# 2                     Audi e-tron GT RS           3.3       250    405
# 3                 Renault Zoe ZE50 R110          11.4       135    315
# 4                     Audi Q4 e-tron 35           9.0       160    285
# ..                                  ...           ...       ...    ...
# 304                 Volkswagen ID.7 Pro           8.0       180    470
# 305               Volkswagen ID.7 Pro S           7.0       180    520
# 306  Polestar 4 Long Range Single Motor           7.4       180    510
# 307    Polestar 4 Long Range Dual Motor           3.8       200    475
# 308            Maserati Grecale Folgore           4.1       220    405
#
#      Efficiency  FastChargeSpeed              Drive  NumberofSeats  \
# 0           183            820.0    All Wheel Drive              5
# 1           209            980.0    All Wheel Drive              4
# 2           210           1000.0    All Wheel Drive              4
# 3           165            230.0  Front Wheel Drive              5
# 4           182            360.0   Rear Wheel Drive              5
# ..          ...              ...                ...            ...
# 304         164            700.0   Rear Wheel Drive              5
# 305         165            800.0   Rear Wheel Drive              5
# 306         184            760.0   Rear Wheel Drive              5
# 307         198            710.0    All Wheel Drive              5
# 308         235            440.0    All Wheel Drive              5
#
#      PriceinGermany  PriceinUK  PriceinUSD  BatteryCapacity  Available  \
# 0          218000.0        NaN   235440.00            118.0       True
# 1          189668.0   142400.0   204841.44             83.7       True
# 2          146050.0   115000.0   157734.00             85.0       True
# 3           36840.0        NaN    39787.20             52.0       True
# 4               NaN        NaN         NaN             52.0       True
# ..              ...        ...         ...              ...        ...
# 304         55000.0    53000.0    59400.00             77.0      False
# 305         60000.0    56000.0    64800.00             86.0      False
# 306         60000.0    55000.0    64800.00             94.0      False
# 307         65000.0    60000.0    70200.00             94.0      False
# 308             NaN   135000.0   168750.00             95.0      False
#
#             Release
# 0      january 2022
# 1      january 2020
# 2        march 2021
# 3     november 2019
# 4         june 2021
# ..              ...
# 304    october 2023
# 305    october 2023
# 306   february 2024
# 307   february 2024
# 308  september 2023
#
# [309 rows x 14 columns]

# %%
cheapEVs.describe()
# Out:
#        Acceleration    TopSpeed       Range  Efficiency  FastChargeSpeed  \
# count    309.000000  309.000000  309.000000  309.000000       306.000000
# mean       7.532039  180.754045  361.440129  199.430421       543.562092
# std        3.127109   38.738187  110.861212   33.021626       247.200836
# min        2.100000  125.000000   95.000000  150.000000       150.000000
# 25%        4.900000  150.000000  275.000000  174.000000       330.000000
# 50%        7.000000  180.000000  370.000000  192.000000       500.000000
# 75%        9.000000  200.000000  440.000000  214.000000       680.000000
# max       19.100000  320.000000  685.000000  295.000000      1240.000000
#
#        NumberofSeats  PriceinGermany      PriceinUK     PriceinUSD  \
# count     309.000000      282.000000     198.000000     291.000000
# mean        5.284790    71039.826241   64255.196970   76500.118488
# std         0.978567    41731.536969   37481.721471   44855.450239
# min         2.000000    21940.000000   25995.000000   23695.200000
# 25%         5.000000    46990.000000   38876.250000   50524.875000
# 50%         5.000000    58752.500000   52682.500000   63428.400000
# 75%         5.000000    77275.000000   76336.500000   83079.000000
# max         7.000000   400000.000000  350000.000000  432000.000000
#
#        BatteryCapacity
# count       309.000000
# mean         71.076052
# std          21.139409
# min          16.700000
# 25%          56.000000
# 50%          74.000000
# 75%          85.000000
# max         123.000000

# %%
# Tesla Stock Market Analysis Dataset
teslaStockPath = "csvData/TSLAstock.csv"
teslaStock = pd.read_csv(teslaStockPath)
teslaStock
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 1     2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2     2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 3     2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# 4     2010-07-07    1.093333    1.108667    0.998667    1.053333    1.053333
# ...          ...         ...         ...         ...         ...         ...
# 3072  2022-09-13  292.899994  297.399994  290.399994  292.130005  292.130005
# 3073  2022-09-14  292.239990  306.000000  291.640015  302.609985  302.609985
# 3074  2022-09-15  301.829987  309.119995  300.720001  303.750000  303.750000
# 3075  2022-09-16  299.609985  303.709991  295.600006  303.350006  303.350006
# 3076  2022-09-19  300.089996  309.839996  297.799988  309.070007  309.070007
#
#          Volume
# 0     257806500
# 1     123282000
# 2      77097000
# 3     103003500
# 4     103825500
# ...         ...
# 3072   68229600
# 3073   72628700
# 3074   64795500
# 3075   86949500
# 3076   60060200
#
# [3077 rows x 7 columns]

# %%
teslaStock.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  3077.000000  3077.000000  3077.000000  3077.000000  3077.000000
# mean     55.502174    56.748047    54.161176    55.495537    55.495537
# std      93.913081    96.085026    91.517219    93.851345    93.851345
# min       1.076000     1.108667     0.998667     1.053333     1.053333
# 25%       8.192667     8.354667     7.970667     8.113333     8.113333
# 50%      15.983333    16.242001    15.687333    16.000668    16.000668
# 75%      23.586666    23.916668    23.229334    23.523333    23.523333
# max     411.470001   414.496674   405.666656   409.970001   409.970001
#
#              Volume
# count  3.077000e+03
# mean   9.340392e+07
# std    8.235816e+07
# min    1.777500e+06
# 25%    4.144350e+07
# 50%    7.541550e+07
# 75%    1.173030e+08
# max    9.140820e+08

# %%
# create a column of average daily stock price by averaging the high and low stock prices
teslaStock["AvgHighLow"] = (teslaStock['High']+teslaStock['Low'])/2
teslaStock["AvgHighLow"]
# Out:
# 0         1.790666
# 1         1.539667
# 2         1.393667
# 3         1.194333
# 4         1.053667
#            ...
# 3072    293.899994
# 3073    298.820007
# 3074    304.919998
# 3075    299.654999
# 3076    303.819992
# Name: AvgHighLow, Length: 3077, dtype: float64

# %%
# convert date column to datetime 
teslaStock['Date'] = pd.to_datetime(teslaStock['Date'])
teslaStock['Date']
# Out:
# 0      2010-06-30
# 1      2010-07-01
# 2      2010-07-02
# 3      2010-07-06
# 4      2010-07-07
#           ...
# 3072   2022-09-13
# 3073   2022-09-14
# 3074   2022-09-15
# 3075   2022-09-16
# 3076   2022-09-19
# Name: Date, Length: 3077, dtype: datetime64[ns]

# %%
#resample by year and calculate average stock price of every year
year_avg_tesla_stock = teslaStock.groupby(teslaStock.Date.dt.year)['AvgHighLow'].mean()
year_avg_tesla_stock[2010]
# Out:
# 1.558524534883721

# %% [markdown]
# # Data Analysis & Results (EDA)

# %% [markdown]
# Carry out EDA on your dataset(s); Describe in this section
#
# ### Need:
# - size
# - shape (distribution)
# - missingness
# - central tendency (mean, median, mode)
# - variability
#
# understand relationship between variables
#
# ### Exploratory
#
# - Look for missing values
# - Look for outlier values
# - Calculate numerical summaries
# - Generate plots to explore relationships
# - Use tables to explore relationships
# - If necessary, transform variables
#
# Univariate, Bivariate, Demensionality Reduction

# %% [markdown]
# ## EDA on the `cheapEVs` dataset

# %%
# Lets look at the size of the cheapEVs dataset
print(cheapEVs.shape)
cheapEVs.describe()
# Out:
# (309, 14)
#        Acceleration    TopSpeed       Range  Efficiency  FastChargeSpeed  \
# count    309.000000  309.000000  309.000000  309.000000       306.000000
# mean       7.532039  180.754045  361.440129  199.430421       543.562092
# std        3.127109   38.738187  110.861212   33.021626       247.200836
# min        2.100000  125.000000   95.000000  150.000000       150.000000
# 25%        4.900000  150.000000  275.000000  174.000000       330.000000
# 50%        7.000000  180.000000  370.000000  192.000000       500.000000
# 75%        9.000000  200.000000  440.000000  214.000000       680.000000
# max       19.100000  320.000000  685.000000  295.000000      1240.000000
#
#        NumberofSeats  PriceinGermany      PriceinUK     PriceinUSD  \
# count     309.000000      282.000000     198.000000     291.000000
# mean        5.284790    71039.826241   64255.196970   76500.118488
# std         0.978567    41731.536969   37481.721471   44855.450239
# min         2.000000    21940.000000   25995.000000   23695.200000
# 25%         5.000000    46990.000000   38876.250000   50524.875000
# 50%         5.000000    58752.500000   52682.500000   63428.400000
# 75%         5.000000    77275.000000   76336.500000   83079.000000
# max         7.000000   400000.000000  350000.000000  432000.000000
#
#        BatteryCapacity
# count       309.000000
# mean         71.076052
# std          21.139409
# min          16.700000
# 25%          56.000000
# 50%          74.000000
# 75%          85.000000
# max         123.000000

# %% [markdown]
# We have 309 observations across 14 variables
#
# Lets take a quick overarching look at the relationships betweent the different variables

# %%
fig = pd.plotting.scatter_matrix(cheapEVs[
    ['Acceleration','TopSpeed', 'Range', 'Efficiency', 'FastChargeSpeed', 'NumberofSeats', 'BatteryCapacity','PriceinUSD']],
                                                                                                             figsize=(14,14))

# %% [markdown]
# An important factor which has a massive influence on other factors is the price of an EV

# %%
# Lets take a deeper dive into that variable, in the standardlized version, 'PriceinUSD'
cheapEVs['PriceinUSD'].describe()
# Out:
# count       291.000000
# mean      76500.118488
# std       44855.450239
# min       23695.200000
# 25%       50524.875000
# 50%       63428.400000
# 75%       83079.000000
# max      432000.000000
# Name: PriceinUSD, dtype: float64

# %% [markdown]
# Out of our 309 observations, 291 of them have a recorded price in our dataset. Average cost being about $76,500
#
# Now lets take a deeper dive into some of more interesting variables related to price

# %%
# Lets see how price affects the acceleration of an EV
sns.scatterplot(data=cheapEVs, x='PriceinUSD', y='Acceleration')
# Out:
# <Axes: xlabel='PriceinUSD', ylabel='Acceleration'>

# %% [markdown]
# It seems to be almost a logarithmic relation between the two variables

# %%
# Lets see the two outliers for this data:
# First, the top left data point with a high acceleration value
cheapEVs[cheapEVs.Acceleration == cheapEVs.Acceleration.max()]
# Out:
#                          Name  Acceleration  TopSpeed  Range  Efficiency  \
# 188  Dacia Spring Electric 45          19.1       125    165         152
#
#      FastChargeSpeed              Drive  NumberofSeats  PriceinGermany  \
# 188            180.0  Front Wheel Drive              4         22550.0
#
#      PriceinUK  PriceinUSD  BatteryCapacity  Available    Release
# 188        NaN     24354.0             25.0       True  july 2022

# %%
# Second, the bottom right data point with a high price
cheapEVs[cheapEVs.PriceinUSD == cheapEVs.PriceinUSD.max()]
# Out:
#                      Name  Acceleration  TopSpeed  Range  Efficiency  \
# 233  Rolls-Royce Spectre            4.5       250    455         220
#
#      FastChargeSpeed            Drive  NumberofSeats  PriceinGermany  \
# 233            540.0  All Wheel Drive              4        400000.0
#
#      PriceinUK  PriceinUSD  BatteryCapacity  Available        Release
# 233   350000.0    432000.0            100.0      False  november 2023

# %%
# Now lets look at the data with these two outliers removed
sns.scatterplot(data=cheapEVs[(cheapEVs.PriceinUSD < cheapEVs.PriceinUSD.max()) & (cheapEVs.Acceleration < cheapEVs.Acceleration.max())], 
                                                                                                        x='PriceinUSD', y='Acceleration')
# Out:
# <Axes: xlabel='PriceinUSD', ylabel='Acceleration'>

# %% [markdown]
# It seems price has a negative relationship with acceleration which makes sense since more expensive cars have a faster acceleration time. However, there seems to be some clustering around 12.5 to 15.0 sec acceleration and 50,000-75,000 USD.

# %%
# Lets take a closer dive into this clustering
cluserEVs = cheapEVs[(cheapEVs.PriceinUSD < 100000.0) & (cheapEVs.PriceinUSD > 50000.0)
                     & (cheapEVs.Acceleration < 15.0) & (cheapEVs.Acceleration > 11.5)]
cluserEVs
# Out:
#                                         Name  Acceleration  TopSpeed  Range  \
# 14                     Mercedes EQV 300 Long          12.1       160    305
# 30               Mercedes EQV 300 Extra-Long          12.1       160    305
# 37            Citroen e-SpaceTourer M 50 kWh          12.1       130    185
# 38           Citroen e-SpaceTourer XL 50 kWh          12.1       130    180
# 39            Citroen e-SpaceTourer M 75 kWh          13.3       130    265
# 40           Citroen e-SpaceTourer XL 75 kWh          13.3       130    260
# 41               Opel Zafira-e Life M 50 kWh          12.1       130    185
# 42               Opel Zafira-e Life L 50 kWh          12.1       130    180
# 43               Opel Zafira-e Life M 75 kWh          13.3       130    265
# 44               Opel Zafira-e Life L 75 kWh          13.3       130    260
# 45       Peugeot e-Traveller Standard 50 kWh          13.1       130    185
# 46           Peugeot e-Traveller Long 50 kWh          13.1       130    180
# 47       Peugeot e-Traveller Standard 75 kWh          14.3       130    265
# 48           Peugeot e-Traveller Long 75 kWh          14.3       130    260
# 82              Toyota PROACE Verso M 75 kWh          13.1       130    265
# 83              Toyota PROACE Verso L 75 kWh          13.1       130    260
# 100                    Mercedes EQV 250 Long          12.0       160    205
# 101              Mercedes EQV 250 Extra-Long          12.0       160    205
# 125           Citroen e-Jumpy Combi M 50 kWh          12.1       130    185
# 126          Citroen e-Jumpy Combi XL 50 kWh          12.1       130    180
# 127           Citroen e-Jumpy Combi M 75 kWh          13.3       130    265
# 128          Citroen e-Jumpy Combi XL 75 kWh          13.3       130    260
# 129             Opel Vivaro-e Combi M 50 kWh          12.1       130    185
# 130             Opel Vivaro-e Combi L 50 kWh          12.1       130    180
# 131             Opel Vivaro-e Combi M 75 kWh          13.3       130    265
# 132             Opel Vivaro-e Combi L 75 kWh          13.3       130    260
# 133   Peugeot e-Expert Combi Standard 50 kWh          13.1       130    185
# 134       Peugeot e-Expert Combi Long 50 kWh          13.1       130    180
# 135   Peugeot e-Expert Combi Standard 75 kWh          14.3       130    265
# 136       Peugeot e-Expert Combi Long 75 kWh          14.3       130    260
# 141        Mercedes eVito Tourer Long 90 kWh          12.0       160    310
# 142  Mercedes eVito Tourer Extra-Long 90 kWh          12.0       160    305
# 143        Mercedes eVito Tourer Long 60 kWh          12.0       160    210
# 144  Mercedes eVito Tourer Extra-Long 60 kWh          12.0       160    205
# 204                  Fiat E-Ulysse L2 50 kWh          12.1       130    185
# 205                  Fiat E-Ulysse L2 75 kWh          13.3       130    265
# 206                  Fiat E-Ulysse L3 50 kWh          12.1       130    180
# 207                  Fiat E-Ulysse L3 75 kWh          13.3       130    260
#
#      Efficiency  FastChargeSpeed              Drive  NumberofSeats  \
# 14          295            310.0  Front Wheel Drive              7
# 30          295            310.0  Front Wheel Drive              7
# 37          250            290.0  Front Wheel Drive              7
# 38          257            290.0  Front Wheel Drive              7
# 39          257            290.0  Front Wheel Drive              7
# 40          262            280.0  Front Wheel Drive              7
# 41          250            290.0  Front Wheel Drive              7
# 42          257            290.0  Front Wheel Drive              7
# 43          257            290.0  Front Wheel Drive              7
# 44          262            280.0  Front Wheel Drive              7
# 45          250            290.0  Front Wheel Drive              7
# 46          257            290.0  Front Wheel Drive              7
# 47          257            290.0  Front Wheel Drive              7
# 48          262            280.0  Front Wheel Drive              7
# 82          257            290.0  Front Wheel Drive              7
# 83          262            280.0  Front Wheel Drive              7
# 100         293            190.0  Front Wheel Drive              7
# 101         293            190.0  Front Wheel Drive              7
# 125         250            290.0  Front Wheel Drive              7
# 126         257            290.0  Front Wheel Drive              7
# 127         257            290.0  Front Wheel Drive              7
# 128         262            280.0  Front Wheel Drive              7
# 129         250            290.0  Front Wheel Drive              7
# 130         257            290.0  Front Wheel Drive              7
# 131         257            290.0  Front Wheel Drive              7
# 132         262            280.0  Front Wheel Drive              7
# 133         250            290.0  Front Wheel Drive              7
# 134         257            290.0  Front Wheel Drive              7
# 135         257            290.0  Front Wheel Drive              7
# 136         262            280.0  Front Wheel Drive              7
# 141         290            310.0  Front Wheel Drive              7
# 142         295            310.0  Front Wheel Drive              7
# 143         286            310.0  Front Wheel Drive              7
# 144         293            300.0  Front Wheel Drive              7
# 204         250            290.0  Front Wheel Drive              7
# 205         257            290.0  Front Wheel Drive              7
# 206         257            290.0  Front Wheel Drive              7
# 207         262            280.0  Front Wheel Drive              7
#
#      PriceinGermany  PriceinUK  PriceinUSD  BatteryCapacity  Available  \
# 14          71626.0    83530.0    77356.08             90.0       True
# 30          72519.0        NaN    78320.52             90.0       True
# 37          53640.0    47495.0    57931.20             46.3       True
# 38          54430.0    48335.0    58784.40             46.3       True
# 39          59640.0        NaN    64411.20             68.0       True
# 40          60430.0        NaN    65264.40             68.0       True
# 41          63250.0    50630.0    68310.00             46.3       True
# 42          64075.0    50990.0    69201.00             46.3       True
# 43          69250.0        NaN    74790.00             68.0       True
# 44          70075.0        NaN    75681.00             68.0       True
# 45          53640.0    49100.0    57931.20             46.3       True
# 46          54430.0    54275.0    58784.40             46.3       True
# 47          59640.0        NaN    64411.20             68.0       True
# 48          60430.0        NaN    65264.40             68.0       True
# 82          64530.0        NaN    69692.40             68.0       True
# 83          65385.0        NaN    70615.80             68.0       True
# 100         68056.0        NaN    73500.48             60.0       True
# 101         68949.0        NaN    74464.92             60.0       True
# 125         51940.0    35795.0    56095.20             46.3       True
# 126         52730.0    35995.0    56948.40             46.3       True
# 127         57940.0        NaN    62575.20             68.0       True
# 128         58730.0        NaN    63428.40             68.0       True
# 129         50992.0    37320.0    55071.36             46.3       True
# 130         51825.0    37520.0    55971.00             46.3       True
# 131         56942.0        NaN    61497.36             68.0       True
# 132         57775.0        NaN    62397.00             68.0       True
# 133         51940.0        NaN    56095.20             46.3       True
# 134         52730.0        NaN    56948.40             46.3       True
# 135         57940.0        NaN    62575.20             68.0       True
# 136         58730.0        NaN    63428.40             68.0       True
# 141         64248.0    68352.0    69387.84             90.0       True
# 142         65140.0    75846.0    70351.20             90.0       True
# 143         60678.0        NaN    65532.24             60.0       True
# 144         61571.0        NaN    66496.68             60.0       True
# 204         55990.0        NaN    60469.20             46.3       True
# 205         61990.0        NaN    66949.20             68.0       True
# 206         56990.0        NaN    61549.20             46.3       True
# 207         62990.0        NaN    68029.20             68.0       True
#
#             Release
# 14   september 2020
# 30     october 2020
# 37    november 2020
# 38    november 2020
# 39    february 2021
# 40    february 2021
# 41    november 2020
# 42    november 2020
# 43    february 2021
# 44    february 2021
# 45    november 2020
# 46    november 2020
# 47    february 2021
# 48    february 2021
# 82     october 2021
# 83     october 2021
# 100    october 2021
# 101    october 2021
# 125   november 2020
# 126   november 2020
# 127   november 2020
# 128   november 2020
# 129    october 2020
# 130    october 2020
# 131    october 2020
# 132    october 2020
# 133   february 2021
# 134   february 2021
# 135   february 2021
# 136   february 2021
# 141    october 2020
# 142    october 2020
# 143    january 2022
# 144    january 2022
# 204       june 2022
# 205       june 2022
# 206       june 2022
# 207       june 2022

# %% [markdown]
# The clustering seems to be caused by different configurations of the same car models. With each model, it seems the different configurations vary in price but seem to mostly have the same acceleration across a model. I think it does not affect the data too much here but is important to keep in mind during analysis where we might opt to only include one configuration across different models.
#
# Now lets look at the distribution of the `PriceinUSD` variable.

# %%
sns.histplot(data=cheapEVs, x='PriceinUSD')
# Out:
# <Axes: xlabel='PriceinUSD', ylabel='Count'>

# %% [markdown]
# The **Rolls-Royce Spectre**, as we saw earlier, seems to skew the price data a lot at a price of 432,000 USD (Ironic the dataset is called cheapEVs). However, there also seem to be quite a few high-priced EVs that skew the data over all. Lets try looking at only the EVs less than 180,000 USD

# %%
cheaperEVs = cheapEVs[cheapEVs.PriceinUSD < 180000]

# %%
# Now lets take another look at the full data scatter plot with the outliers removed
fig = pd.plotting.scatter_matrix(cheaperEVs[
    ['Acceleration','TopSpeed', 'Range', 'Efficiency', 'FastChargeSpeed', 'NumberofSeats', 'BatteryCapacity','PriceinUSD']],
                                                                                                             figsize=(14,14))

# %% [markdown]
# For the scatter plots with `PriceinUSD` in them, it seems the plots have more spread and variability then what we saw earlier with the outliers
#
# Lets also see how removing the outliers affected the centrality and variability of `PriceinUSD`

# %%
cheaperEVs.PriceinUSD.describe()
# Out:
# count       282.000000
# mean      71159.928227
# std       31511.296487
# min       23695.200000
# 25%       50206.500000
# 50%       62553.600000
# 75%       78315.390000
# max      170398.080000
# Name: PriceinUSD, dtype: float64

# %%
sns.scatterplot(data=cheapEVs, x='Range', y='FastChargeSpeed')
# Out:
# <Axes: xlabel='Range', ylabel='FastChargeSpeed'>

# %% [markdown]
# Interesting. There almost seems to be two linear relations between the two variables here
